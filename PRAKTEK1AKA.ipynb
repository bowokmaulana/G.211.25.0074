# %% [markdown]
# <a href="https://colab.research.google.com/github/bowokmaulana/G.211.25.0074/blob/main/PRAKTEK1AKA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Maulana Tri W
# G.211.25.0074

# %%
n = 8
for i in range (1,n+1):
  print ("Hello word !!!")
# Out:
# Hello word !!!
# Hello word !!!
# Hello word !!!
# Hello word !!!
# Hello word !!!
# Hello word !!!
# Hello word !!!
# Hello word !!!

# %%
def total(angka ,n):
  jumlah = 0
  for i in range (n):
    jumlah = jumlah + angka [i]
  return jumlah
angka = [4,5,6,3]
n = len (angka)
print(total (angka,n))
# Out:
# 24

# %%
a= 3
b= 3
angka =[(4,2,6), (3,7,9), (2,5,8)]
total = 0

for i in range(a):
  for j in range(b):
    total += angka [i][j]
print (total)
# Out:
# 46

# %% [markdown]
# mencari bilangan faktorial

# %%
n = 4
hasil = 2

for i in range(1, n+1):
    hasil = hasil * i

print(hasil)
# Out:
# 48
