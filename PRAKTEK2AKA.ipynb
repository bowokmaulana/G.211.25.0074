# %% [markdown]
# <a href="https://colab.research.google.com/github/bowokmaulana/G.211.25.0074/blob/main/PRAKTEK2AKA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Maulana Tri W
# G.211.25.0074

# %%
def find_maximum (T):
  m = len(T)
  for i in range(m - 1, -1 ,-1):
    if T[i] is not None:
      return i
  return None

def find_maximum_value(T):
  m = len(T)
  for i in range(m - 1 , -1 ,-1):
    if T[i] is not None:
      return T[i]
  return None

T = [None, 5 , None , 9 , None, None]

print(find_maximum(T))
print(find_maximum_value(T))
# Out:
# 3
# 9
